# %%
# %matplotlib inline

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (18, 4)

# %%
vuno_data = pandas.read_csv('/Users/ay/tmp/results_vuplusuno.csv', sep=' ', dtype=np.float64)

# %%
vuno_match_latency = vuno_data['match_found'] - vuno_data['ir_left_end']
vuno_match_latency = vuno_match_latency[vuno_match_latency > 0.1]

# %%
plt.plot(vuno_match_latency)

# %%
vuno_disappear_latency = vuno_data['match_disappeared'] - vuno_data['ir_right_end']
vuno_disappear_latency = vuno_disappear_latency[vuno_disappear_latency > 0.1]

# %%
plt.plot(vuno_disappear_latency)

# %%
vuno_keypress_left = vuno_data['ir_left_end'] - vuno_data['ir_left_start']
vuno_keypress_left = vuno_keypress_left[vuno_keypress_left < 0.25]

# %%
plt.plot(vuno_keypress_left)

# %%
vuno_keypress_right = vuno_data['ir_right_end'] - vuno_data['ir_right_start']
vuno_keypress_right = vuno_keypress_right[vuno_keypress_right < 0.25]

# %%
plt.plot(vuno_keypress_right)

# %%
moto_data = pandas.read_csv('/Users/ay/tmp/results_motorola.csv', sep=' ', dtype=np.float64)

# %%
moto_match_latency = moto_data['match_found'] - moto_data['ir_left_end']
moto_match_latency = moto_match_latency[moto_match_latency > 0.5]

# %%
plt.plot(moto_match_latency)

# %%
moto_disappear_latency = moto_data['match_disappeared'] - moto_data['ir_right_end']
moto_disappear_latency = moto_disappear_latency[moto_disappear_latency > 0.5]

# %%
plt.plot(moto_disappear_latency)

# %%
moto_keypress_left = moto_data['ir_left_end'] - moto_data['ir_left_start']
moto_keypress_left = moto_keypress_left[moto_keypress_left < 0.1]

# %%
plt.plot(moto_keypress_left)

# %%
moto_keypress_right = moto_data['ir_right_end'] - moto_data['ir_right_start']
moto_keypress_right = moto_keypress_right[moto_keypress_right < 0.1]

# %%
plt.plot(moto_keypress_right)
